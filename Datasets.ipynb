# %% [markdown]
# irs.gov/statistics

# %%
import pandas as pd

# %%
df = pd.read_excel('https://www.irs.gov/pub/irs-soi/15otidb1.xls')
df
#ugh weird excel formatting
# Out:
#    Table 1. Number of Returns, Total Receipts, Business Receipts, Net Income (less deficit),\nNet Income, and Deficit, by Form of Business, Tax Years 1980-2015  ... Unnamed: 38
# 0   [All figures are estimates based on samples--m...                                                                                                            ...         NaN
# 1                                                 NaN                                                                                                            ...         NaN
# 2                              Form of business, item                                                                                                            ...         NaN
# 3                                                 NaN                                                                                                            ...         NaN
# ...

# %%
df.columns[0].split(',')
# Out:
# ['Table 1. Number of Returns',
#  ' Total Receipts',
#  ' Business Receipts',
#  ' Net Income (less deficit)',
#  '\nNet Income',
#  ' and Deficit',
#  ' by Form of Business',
#  ' Tax Years 1980-2015']
